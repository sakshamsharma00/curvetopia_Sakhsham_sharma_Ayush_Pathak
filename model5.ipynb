# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import svgwrite

# Function to read CSV without headers
def read_csv_no_headers(csv_path):
    """Read CSV file without headers and return structured data."""
    data = np.genfromtxt(csv_path, delimiter=',')
    
    # Assuming the order is [strokes, z, y, x]
    strokes = data[:, 0]
    y = data[:, 2]
    x = data[:, 3]
    
    # Combine x and y into coordinate pairs
    paths = []
    for stroke in np.unique(strokes):
        path = np.column_stack((x[strokes == stroke], y[strokes == stroke]))
        paths.append(path)
    
    return paths

# Function to normalize paths
def normalize_paths(paths):
    """Normalize the paths to a common scale, e.g., between 0 and 1."""
    all_points = np.concatenate(paths, axis=0)
    min_val, max_val = np.min(all_points, axis=0), np.max(all_points, axis=0)
    paths_normalized = [(path - min_val) / (max_val - min_val) for path in paths]
    return paths_normalized, min_val, max_val

# Function to approximate a path with a cubic Bézier curve
def approximate_cubic_bezier(path):
    """Approximate a path with a cubic Bézier curve."""
    n = len(path)
    if n < 4:
        # Pad or repeat points to create a cubic Bézier
        padded_path = np.pad(path, ((0, 4-n), (0, 0)), mode='edge')
        return padded_path
    
    # Simplified approach: take the first 4 points
    bezier_curve = path[:4]
    return bezier_curve

# Function to convert paths to Bézier curves
def paths_to_bezier(paths):
    """Convert paths to Bézier curves."""
    beziers = []
    for path in paths:
        bezier_curve = approximate_cubic_bezier(path)
        beziers.append(bezier_curve)
    return beziers

# Function to pad paths to ensure uniform length
def pad_paths(paths, target_length):
    """Pads each path with zeros to ensure uniform length."""
    padded_paths = []
    for path in paths:
        if len(path) < target_length:
            padding = np.zeros((target_length - len(path), 2))
            padded_path = np.vstack([path, padding])
        else:
            padded_path = path[:target_length]
        padded_paths.append(padded_path)
    return np.array(padded_paths)

# Function to align the number of samples between input and solution paths
def align_sample_numbers(input_paths, solution_paths):
    """Align the number of samples between input and solution paths."""
    input_count = len(input_paths)
    solution_count = len(solution_paths)
    
    if input_count > solution_count:
        solution_paths = np.tile(solution_paths, (input_count // solution_count + 1, 1, 1))[:input_count]
    elif solution_count > input_count:
        input_paths = np.tile(input_paths, (solution_count // input_count + 1, 1, 1))[:solution_count]
    
    return input_paths, solution_paths

# Function to convert Bézier curves into an SVG file
def bezier_to_svg(bezier_curves, filename="output.svg"):
    """Convert Bézier curves into an SVG file."""
    dwg = svgwrite.Drawing(filename, profile='tiny')

    for curve in bezier_curves:
        path_data = f"M {curve[0][0]} {curve[0][1]} "  # Move to the start point
        path_data += f"C {curve[1][0]} {curve[1][1]}, {curve[2][0]} {curve[2][1]}, {curve[3][0]} {curve[3][1]}"  # Cubic Bézier command
        dwg.add(dwg.path(d=path_data, stroke=svgwrite.rgb(0, 0, 0, '%'), fill="none"))

    dwg.save()

# Example usage
input_csv_path = 'frag0.csv'
solution_csv_path = 'frag01_sol.csv'

input_paths = read_csv_no_headers(input_csv_path)
solution_paths = read_csv_no_headers(solution_csv_path)

input_paths_normalized, _, _ = normalize_paths(input_paths)
solution_paths_normalized, _, _ = normalize_paths(solution_paths)

# Convert to Bézier curves
input_beziers = paths_to_bezier(input_paths_normalized)
solution_beziers = paths_to_bezier(solution_paths_normalized)

# Align the number of samples
input_beziers_aligned, solution_beziers_aligned = align_sample_numbers(input_beziers, solution_beziers)

# Pad or trim to ensure uniform length
target_length = max(len(bezier) for bezier in input_beziers_aligned)
input_beziers_padded = pad_paths(input_beziers_aligned, target_length)
solution_beziers_padded = pad_paths(solution_beziers_aligned, target_length)

# Flatten the data for input to the model
X_train = np.array([np.ravel(bezier) for bezier in input_beziers_padded])
Y_train = np.array([np.ravel(bezier) for bezier in solution_beziers_padded])

# Check that the input and output data have the same number of samples
assert X_train.shape[0] == Y_train.shape[0], "Mismatch in number of samples"

# Define the model
def create_bezier_model(input_shape):
    model = tf.keras.Sequential([
        layers.Dense(128, activation='relu', input_shape=input_shape),
        layers.Dense(256, activation='relu'),
        layers.Dense(512, activation='relu'),
        layers.Dense(input_shape[0])  # Output size should match the flattened Bézier parameters
    ])
    return model

input_shape = (X_train.shape[1],)
bezier_model = create_bezier_model(input_shape)

# Compile the model
bezier_model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
bezier_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split=0.1)

# Call the visualization function for both input and solution Bézier curves
bezier_to_svg(input_beziers_padded, filename="ip.svg")
bezier_to_svg(solution_beziers_padded, filename="sp.svg")
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 774ms/step - loss: 0.2504 - val_loss: 0.3452
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1772 - val_loss: 0.3382
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1277 - val_loss: 0.3296
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0967 - val_loss: 0.3198
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0864 - val_loss: 0.3103
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0925 - val_loss: 0.3039
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0995 - val_loss: 0.3015
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0974 - val_loss: 0.3022
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0890 - val_loss: 0.3045
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0807 - val_loss: 0.3072
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0756 - val_loss: 0.3094
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0740 - val_loss: 0.3107
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0744 - val_loss: 0.3108
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0752 - val_loss: 0.3097
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0753 - val_loss: 0.3075
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0745 - val_loss: 0.3043
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0726 - val_loss: 0.3003
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0701 - val_loss: 0.2956
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0678 - val_loss: 0.2906
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0658 - val_loss: 0.2855
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0646 - val_loss: 0.2807
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0639 - val_loss: 0.2766
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0636 - val_loss: 0.2734
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0632 - val_loss: 0.2711
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0624 - val_loss: 0.2696
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0612 - val_loss: 0.2684
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0598 - val_loss: 0.2672
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0586 - val_loss: 0.2658
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0575 - val_loss: 0.2639
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0568 - val_loss: 0.2614
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0562 - val_loss: 0.2584
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0555 - val_loss: 0.2550
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0549 - val_loss: 0.2512
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0540 - val_loss: 0.2472
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0531 - val_loss: 0.2431
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0520 - val_loss: 0.2389
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0510 - val_loss: 0.2349
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0501 - val_loss: 0.2309
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0492 - val_loss: 0.2271
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0484 - val_loss: 0.2236
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0476 - val_loss: 0.2201
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0467 - val_loss: 0.2166
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0458 - val_loss: 0.2133
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0449 - val_loss: 0.2100
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0440 - val_loss: 0.2066
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0432 - val_loss: 0.2028
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0424 - val_loss: 0.1986
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0417 - val_loss: 0.1941
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0410 - val_loss: 0.1894
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0403 - val_loss: 0.1847
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0397 - val_loss: 0.1799
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0392 - val_loss: 0.1752
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0387 - val_loss: 0.1704
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0382 - val_loss: 0.1659
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0379 - val_loss: 0.1616
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0375 - val_loss: 0.1576
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0372 - val_loss: 0.1535
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0369 - val_loss: 0.1496
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0367 - val_loss: 0.1458
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0364 - val_loss: 0.1422
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0362 - val_loss: 0.1388
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0360 - val_loss: 0.1356
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0358 - val_loss: 0.1324
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0356 - val_loss: 0.1296
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0353 - val_loss: 0.1270
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0351 - val_loss: 0.1247
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0349 - val_loss: 0.1228
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0347 - val_loss: 0.1210
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0345 - val_loss: 0.1193
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0344 - val_loss: 0.1177
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0342 - val_loss: 0.1160
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0340 - val_loss: 0.1145
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0339 - val_loss: 0.1131
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0339 - val_loss: 0.1122
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0337 - val_loss: 0.1113
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0336 - val_loss: 0.1103
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0335 - val_loss: 0.1094
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0334 - val_loss: 0.1086
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0333 - val_loss: 0.1079
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0332 - val_loss: 0.1073
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0332 - val_loss: 0.1066
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0331 - val_loss: 0.1060
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0331 - val_loss: 0.1056
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0330 - val_loss: 0.1053
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0329 - val_loss: 0.1050
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0329 - val_loss: 0.1050
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0328 - val_loss: 0.1048
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0327 - val_loss: 0.1045
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0327 - val_loss: 0.1044
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0326 - val_loss: 0.1043
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0325 - val_loss: 0.1042
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0326 - val_loss: 0.1041
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0324 - val_loss: 0.1040
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0324 - val_loss: 0.1037
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0324 - val_loss: 0.1034
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0323 - val_loss: 0.1034
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0322 - val_loss: 0.1033
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0322 - val_loss: 0.1030
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0321 - val_loss: 0.1027
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0321 - val_loss: 0.1026

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import svgwrite

# Function to read CSV without headers
def read_csv_no_headers(csv_path):
    """Read CSV file without headers and return structured data."""
    data = np.genfromtxt(csv_path, delimiter=',')
    
    # Assuming the order is [strokes, z, y, x]
    strokes = data[:, 0]
    y = data[:, 2]
    x = data[:, 3]
    
    # Combine x and y into coordinate pairs
    paths = []
    for stroke in np.unique(strokes):
        path = np.column_stack((x[strokes == stroke], y[strokes == stroke]))
        paths.append(path)
    
    return paths

# Function to normalize paths
def normalize_paths(paths):
    """Normalize the paths to a common scale, e.g., between 0 and 1."""
    all_points = np.concatenate(paths, axis=0)
    min_val, max_val = np.min(all_points, axis=0), np.max(all_points, axis=0)
    paths_normalized = [(path - min_val) / (max_val - min_val) for path in paths]
    return paths_normalized, min_val, max_val

# Function to approximate a path with a cubic Bézier curve
def approximate_cubic_bezier(path):
    """Approximate a path with a cubic Bézier curve."""
    n = len(path)
    if n < 4:
        # Pad or repeat points to create a cubic Bézier
        padded_path = np.pad(path, ((0, 4-n), (0, 0)), mode='edge')
        return padded_path
    
    # Simplified approach: take the first 4 points
    bezier_curve = path[:4]
    return bezier_curve

# Function to convert paths to Bézier curves
def paths_to_bezier(paths):
    """Convert paths to Bézier curves."""
    beziers = []
    for path in paths:
        bezier_curve = approximate_cubic_bezier(path)
        beziers.append(bezier_curve)
    return beziers

# Function to pad paths to ensure uniform length
def pad_paths(paths, target_length):
    """Pads each path with zeros to ensure uniform length."""
    padded_paths = []
    for path in paths:
        if len(path) < target_length:
            padding = np.zeros((target_length - len(path), 2))
            padded_path = np.vstack([path, padding])
        else:
            padded_path = path[:target_length]
        padded_paths.append(padded_path)
    return np.array(padded_paths)

# Function to align the number of samples between input and solution paths
def align_sample_numbers(input_paths, solution_paths):
    """Align the number of samples between input and solution paths."""
    input_count = len(input_paths)
    solution_count = len(solution_paths)
    
    if input_count > solution_count:
        solution_paths = np.tile(solution_paths, (input_count // solution_count + 1, 1, 1))[:input_count]
    elif solution_count > input_count:
        input_paths = np.tile(input_paths, (solution_count // input_count + 1, 1, 1))[:solution_count]
    
    return input_paths, solution_paths

# Function to convert Bézier curves into an SVG file
def bezier_to_svg(bezier_curves, filename="output.svg"):
    """Convert Bézier curves into an SVG file."""
    dwg = svgwrite.Drawing(filename, profile='tiny')

    for curve in bezier_curves:
        if len(curve) < 4:
            continue
        path_data = f"M {curve[0][0]} {curve[0][1]} "  # Move to the start point
        path_data += f"C {curve[1][0]} {curve[1][1]}, {curve[2][0]} {curve[2][1]}, {curve[3][0]} {curve[3][1]}"  # Cubic Bézier command
        dwg.add(dwg.path(d=path_data, stroke=svgwrite.rgb(0, 0, 0, '%'), fill="none"))

    dwg.save()

# Example usage
input_csv_path = 'frag0.csv'
solution_csv_path = 'frag01_sol.csv'

input_paths = read_csv_no_headers(input_csv_path)
solution_paths = read_csv_no_headers(solution_csv_path)

input_paths_normalized, _, _ = normalize_paths(input_paths)
solution_paths_normalized, _, _ = normalize_paths(solution_paths)

# Convert to Bézier curves
input_beziers = paths_to_bezier(input_paths_normalized)
solution_beziers = paths_to_bezier(solution_paths_normalized)

# Align the number of samples
input_beziers_aligned, solution_beziers_aligned = align_sample_numbers(input_beziers, solution_beziers)

# Pad or trim to ensure uniform length
target_length = max(len(bezier) for bezier in input_beziers_aligned)
input_beziers_padded = pad_paths(input_beziers_aligned, target_length)
solution_beziers_padded = pad_paths(solution_beziers_aligned, target_length)

# Flatten the data for input to the model
X_train = np.array([np.ravel(bezier) for bezier in input_beziers_padded])
Y_train = np.array([np.ravel(bezier) for bezier in solution_beziers_padded])

# Check that the input and output data have the same number of samples
assert X_train.shape[0] == Y_train.shape[0], "Mismatch in number of samples"

# Define the model
def create_bezier_model(input_shape):
    model = tf.keras.Sequential([
        layers.Dense(128, activation='relu', input_shape=input_shape),
        layers.Dense(256, activation='relu'),
        layers.Dense(512, activation='relu'),
        layers.Dense(input_shape[0])  # Output size should match the flattened Bézier parameters
    ])
    return model

input_shape = (X_train.shape[1],)
bezier_model = create_bezier_model(input_shape)

# Compile the model
bezier_model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
bezier_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split=0.1)

# Visualize the data
bezier_to_svg(input_beziers_padded, filename="input_paths.svg")
bezier_to_svg(solution_beziers_padded, filename="solution_paths.svg")
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 808ms/step - loss: 0.2276 - val_loss: 0.3442
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1686 - val_loss: 0.3362
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1260 - val_loss: 0.3268
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0986 - val_loss: 0.3163
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0875 - val_loss: 0.3065
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0908 - val_loss: 0.3001
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0962 - val_loss: 0.2978
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0946 - val_loss: 0.2985
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0875 - val_loss: 0.3007
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0800 - val_loss: 0.3035
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0750 - val_loss: 0.3060
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0728 - val_loss: 0.3075
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0724 - val_loss: 0.3078
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0724 - val_loss: 0.3069
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0719 - val_loss: 0.3050
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0708 - val_loss: 0.3020
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0690 - val_loss: 0.2981
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0669 - val_loss: 0.2935
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0647 - val_loss: 0.2884
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0627 - val_loss: 0.2830
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0612 - val_loss: 0.2778
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0600 - val_loss: 0.2734
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0590 - val_loss: 0.2698
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0580 - val_loss: 0.2668
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0569 - val_loss: 0.2645
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0557 - val_loss: 0.2624
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0545 - val_loss: 0.2603
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0533 - val_loss: 0.2579
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0520 - val_loss: 0.2551
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0508 - val_loss: 0.2519
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0496 - val_loss: 0.2482
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0486 - val_loss: 0.2442
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0476 - val_loss: 0.2399
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0466 - val_loss: 0.2355
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0457 - val_loss: 0.2312
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0448 - val_loss: 0.2269
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0440 - val_loss: 0.2228
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0431 - val_loss: 0.2188
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0422 - val_loss: 0.2148
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0414 - val_loss: 0.2109
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0408 - val_loss: 0.2069
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0402 - val_loss: 0.2029
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0397 - val_loss: 0.1988
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0393 - val_loss: 0.1946
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0388 - val_loss: 0.1903
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0384 - val_loss: 0.1860
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0380 - val_loss: 0.1818
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0377 - val_loss: 0.1779
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0373 - val_loss: 0.1743
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0370 - val_loss: 0.1708
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0367 - val_loss: 0.1674
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0363 - val_loss: 0.1639
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0360 - val_loss: 0.1602
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0357 - val_loss: 0.1566
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0354 - val_loss: 0.1530
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0351 - val_loss: 0.1498
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0349 - val_loss: 0.1466
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0346 - val_loss: 0.1434
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0344 - val_loss: 0.1403
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0342 - val_loss: 0.1372
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0339 - val_loss: 0.1341
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0337 - val_loss: 0.1310
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0335 - val_loss: 0.1279
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0334 - val_loss: 0.1251
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0332 - val_loss: 0.1227
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0330 - val_loss: 0.1205
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0328 - val_loss: 0.1184
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0327 - val_loss: 0.1165
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0326 - val_loss: 0.1147
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0325 - val_loss: 0.1131
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0324 - val_loss: 0.1117
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0323 - val_loss: 0.1105
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0323 - val_loss: 0.1096
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0322 - val_loss: 0.1089
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0321 - val_loss: 0.1082
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0320 - val_loss: 0.1076
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0320 - val_loss: 0.1073
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0319 - val_loss: 0.1072
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0319 - val_loss: 0.1071
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0318 - val_loss: 0.1071
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0317 - val_loss: 0.1070
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0317 - val_loss: 0.1070
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0316 - val_loss: 0.1070
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0315 - val_loss: 0.1069
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0315 - val_loss: 0.1068
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0314 - val_loss: 0.1068
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0313 - val_loss: 0.1068
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0313 - val_loss: 0.1067
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0312 - val_loss: 0.1066
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0312 - val_loss: 0.1064
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0311 - val_loss: 0.1063
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0310 - val_loss: 0.1062
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0309 - val_loss: 0.1061
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0309 - val_loss: 0.1060
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0308 - val_loss: 0.1060
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0308 - val_loss: 0.1060
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0307 - val_loss: 0.1060
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0306 - val_loss: 0.1060
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0306 - val_loss: 0.1060
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0305 - val_loss: 0.1059

# %%
import numpy as np
import svgwrite

def bezier_to_svg(bezier_curves, filename="output.svg"):
    """Convert Bézier curves into an SVG file."""
    # Check if bezier_curves is empty
    if bezier_curves.size == 0:
        print("No Bézier curves to visualize.")
        return
    
    # Create a new SVG drawing
    dwg = svgwrite.Drawing(filename, profile='tiny')

    # Set default stroke color and width
    stroke_color = 'black'
    stroke_width = 2
    
    for curve in bezier_curves:
        if curve.size == 0 or len(curve) < 4:
            print("Insufficient points for a Bézier curve.")
            continue
        
        # Ensure coordinates are valid
        try:
            path_data = f"M {curve[0][0]} {curve[0][1]} "  # Move to the start point
            path_data += f"C {curve[1][0]} {curve[1][1]}, {curve[2][0]} {curve[2][1]}, {curve[3][0]} {curve[3][1]}"  # Cubic Bézier command
            dwg.add(dwg.path(d=path_data, stroke=stroke_color, fill="none", stroke_width=stroke_width))
        except Exception as e:
            print(f"Error creating path: {e}")
    
    dwg.save()
    print(f"SVG file saved as {filename}")

# Example usage
input_csv_path = 'frag0.csv'
solution_csv_path = 'frag01_sol.csv'

def read_csv_no_headers(csv_path):
    """Read CSV file without headers and return structured data."""
    data = np.genfromtxt(csv_path, delimiter=',')
    
    strokes = data[:, 0]
    y = data[:, 2]
    x = data[:, 3]
    
    paths = []
    for stroke in np.unique(strokes):
        path = np.column_stack((x[strokes == stroke], y[strokes == stroke]))
        paths.append(path)
    
    return paths

def normalize_paths(paths):
    """Normalize the paths to a common scale, e.g., between 0 and 1."""
    all_points = np.concatenate(paths, axis=0)
    min_val, max_val = np.min(all_points, axis=0), np.max(all_points, axis=0)
    paths_normalized = [(path - min_val) / (max_val - min_val) for path in paths]
    return paths_normalized, min_val, max_val

def approximate_cubic_bezier(path):
    """Approximate a path with a cubic Bézier curve."""
    n = len(path)
    if n < 4:
        padded_path = np.pad(path, ((0, 4-n), (0, 0)), mode='edge')
        return padded_path
    
    bezier_curve = path[:4]
    return bezier_curve

def paths_to_bezier(paths):
    """Convert paths to Bézier curves."""
    beziers = []
    for path in paths:
        bezier_curve = approximate_cubic_bezier(path)
        beziers.append(bezier_curve)
    return beziers

def pad_paths(paths, target_length):
    """Pads each path with zeros to ensure uniform length."""
    padded_paths = []
    for path in paths:
        if len(path) < target_length:
            padding = np.zeros((target_length - len(path), 2))
            padded_path = np.vstack([path, padding])
        else:
            padded_path = path[:target_length]
        padded_paths.append(padded_path)
    return np.array(padded_paths)

def align_sample_numbers(input_paths, solution_paths):
    """Align the number of samples between input and solution paths."""
    input_count = len(input_paths)
    solution_count = len(solution_paths)
    
    if input_count > solution_count:
        solution_paths = np.tile(solution_paths, (input_count // solution_count + 1, 1, 1))[:input_count]
    elif solution_count > input_count:
        input_paths = np.tile(input_paths, (solution_count // input_count + 1, 1, 1))[:solution_count]
    
    return input_paths, solution_paths

# Read and process data
input_paths = read_csv_no_headers(input_csv_path)
solution_paths = read_csv_no_headers(solution_csv_path)

input_paths_normalized, _, _ = normalize_paths(input_paths)
solution_paths_normalized, _, _ = normalize_paths(solution_paths)

# Convert to Bézier curves
input_beziers = paths_to_bezier(input_paths_normalized)
solution_beziers = paths_to_bezier(solution_paths_normalized)

# Align the number of samples
input_beziers_aligned, solution_beziers_aligned = align_sample_numbers(input_beziers, solution_beziers)

# Pad or trim to ensure uniform length
target_length = max(len(bezier) for bezier in input_beziers_aligned)
input_beziers_padded = pad_paths(input_beziers_aligned, target_length)
solution_beziers_padded = pad_paths(solution_beziers_aligned, target_length)

# Save Bézier curves as SVG
bezier_to_svg(input_beziers_padded, filename="input_pat.svg")
bezier_to_svg(solution_beziers_padded, filename="solution_pat.svg")
# Out:
# SVG file saved as input_pat.svg
# SVG file saved as solution_pat.svg

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import svgwrite
import cairosvg

# Function to read CSV without headers
def read_csv_no_headers(csv_path):
    """Read CSV file without headers and return structured data."""
    data = np.genfromtxt(csv_path, delimiter=',')
    
    # Assuming the order is [strokes, z, y, x]
    strokes = data[:, 0]
    y = data[:, 2]
    x = data[:, 3]
    
    # Combine x and y into coordinate pairs
    paths = []
    for stroke in np.unique(strokes):
        path = np.column_stack((x[strokes == stroke], y[strokes == stroke]))
        paths.append(path)
    
    return paths

# Function to normalize paths
def normalize_paths(paths):
    """Normalize the paths to a common scale, e.g., between 0 and 1."""
    all_points = np.concatenate(paths, axis=0)
    min_val, max_val = np.min(all_points, axis=0), np.max(all_points, axis=0)
    paths_normalized = [(path - min_val) / (max_val - min_val) for path in paths]
    return paths_normalized, min_val, max_val

# Function to approximate a path with a cubic Bézier curve
def approximate_cubic_bezier(path):
    """Approximate a path with a cubic Bézier curve."""
    n = len(path)
    if n < 4:
        # Pad or repeat points to create a cubic Bézier
        padded_path = np.pad(path, ((0, 4-n), (0, 0)), mode='edge')
        return padded_path
    
    # Simplified approach: take the first 4 points
    bezier_curve = path[:4]
    return bezier_curve

# Function to convert paths to Bézier curves
def paths_to_bezier(paths):
    """Convert paths to Bézier curves."""
    beziers = []
    for path in paths:
        bezier_curve = approximate_cubic_bezier(path)
        beziers.append(bezier_curve)
    return beziers

# Function to pad paths to ensure uniform length
def pad_paths(paths, target_length):
    """Pads each path with zeros to ensure uniform length."""
    padded_paths = []
    for path in paths:
        if len(path) < target_length:
            padding = np.zeros((target_length - len(path), 2))
            padded_path = np.vstack([path, padding])
        else:
            padded_path = path[:target_length]
        padded_paths.append(padded_path)
    return np.array(padded_paths)

# Function to align the number of samples between input and solution paths
def align_sample_numbers(input_paths, solution_paths):
    """Align the number of samples between input and solution paths."""
    input_count = len(input_paths)
    solution_count = len(solution_paths)
    
    if input_count > solution_count:
        solution_paths = np.tile(solution_paths, (input_count // solution_count + 1, 1, 1))[:input_count]
    elif solution_count > input_count:
        input_paths = np.tile(input_paths, (solution_count // input_count + 1, 1, 1))[:solution_count]
    
    return input_paths, solution_paths

# Function to convert Bézier curves into an SVG file
def bezier_to_svg(bezier_curves, filename="output.svg"):
    """Convert Bézier curves into an SVG file."""
    dwg = svgwrite.Drawing(filename, profile='tiny')

    for curve in bezier_curves:
        path_data = f"M {curve[0][0]} {curve[0][1]} "  # Move to the start point
        path_data += f"C {curve[1][0]} {curve[1][1]}, {curve[2][0]} {curve[2][1]}, {curve[3][0]} {curve[3][1]}"  # Cubic Bézier command
        dwg.add(dwg.path(d=path_data, stroke=svgwrite.rgb(0, 0, 0, '%'), fill="none"))

    dwg.save()

# Function to rasterize SVG to PNG
def polylines2svg(paths_XYs, svg_path):
    """Rasterize polylines into SVG and convert to PNG."""
    W, H = 0, 0
    for path_XYs in paths_XYs:
        for XY in path_XYs:
            W, H = max(W, np.max(XY[:, 0])), max(H, np.max(XY[:, 1]))
    padding = 0.1
    W, H = int(W + padding * W), int(H + padding * H)
    
    # Create a new SVG drawing
    dwg = svgwrite.Drawing(svg_path, profile='tiny', shape_rendering='crispEdges')
    group = dwg.g()
    
    for i, path in enumerate(paths_XYs):
        path_data = []
        for XY in path:
            path_data.append(("M", (XY[0, 0], XY[0, 1])))
            for j in range(1, len(XY)):
                path_data.append(("L", (XY[j, 0], XY[j, 1])))
            if not np.allclose(XY[0], XY[-1]):
                path_data.append(("Z", None))
        group.add(dwg.path(d=path_data, fill='none', stroke='black', stroke_width=2))
    dwg.add(group)
    dwg.save()
    
    png_path = svg_path.replace('.svg', '.png')
    fact = max(1, 1024 // min(H, W))
    cairosvg.svg2png(url=svg_path, write_to=png_path,
                     parent_width=W, parent_height=H,
                     output_width=fact * W, output_height=fact * H,
                     background_color='white')
    return png_path

# Example usage
input_csv_path = 'frag0.csv'
solution_csv_path = 'frag01_sol.csv'

input_paths = read_csv_no_headers(input_csv_path)
solution_paths = read_csv_no_headers(solution_csv_path)

input_paths_normalized, _, _ = normalize_paths(input_paths)
solution_paths_normalized, _, _ = normalize_paths(solution_paths)

# Convert to Bézier curves
input_beziers = paths_to_bezier(input_paths_normalized)
solution_beziers = paths_to_bezier(solution_paths_normalized)

# Align the number of samples
input_beziers_aligned, solution_beziers_aligned = align_sample_numbers(input_beziers, solution_beziers)

# Pad or trim to ensure uniform length
target_length = max(len(bezier) for bezier in input_beziers_aligned)
input_beziers_padded = pad_paths(input_beziers_aligned, target_length)
solution_beziers_padded = pad_paths(solution_beziers_aligned, target_length)

# Flatten the data for input to the model
X_train = np.array([np.ravel(bezier) for bezier in input_beziers_padded])
Y_train = np.array([np.ravel(bezier) for bezier in solution_beziers_padded])

# Check that the input and output data have the same number of samples
assert X_train.shape[0] == Y_train.shape[0], "Mismatch in number of samples"

# Define the model
def create_bezier_model(input_shape):
    model = tf.keras.Sequential([
        layers.Dense(128, activation='relu', input_shape=input_shape),
        layers.Dense(256, activation='relu'),
        layers.Dense(512, activation='relu'),
        layers.Dense(input_shape[0])  # Output size should match the flattened Bézier parameters
    ])
    return model

input_shape = (X_train.shape[1],)
bezier_model = create_bezier_model(input_shape)

# Compile the model
bezier_model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
bezier_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split=0.1)

# Visualize and rasterize the results
input_svg_path = "input_beziers.svg"
solution_svg_path = "solution_beziers.svg"

bezier_to_svg(input_beziers_padded, filename=input_svg_path)
bezier_to_svg(solution_beziers_padded, filename=solution_svg_path)

input_png_path = polylines2svg(input_beziers_padded, svg_path=input_svg_path)
solution_png_path = polylines2svg(solution_beziers_padded, svg_path=solution_svg_path)

print(f"Input PNG saved to: {input_png_path}")
print(f"Solution PNG saved to: {solution_png_path}")
# Out:
# C:\Users\Ayush Pathak\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 799ms/step - loss: 0.2450 - val_loss: 0.3450
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1819 - val_loss: 0.3381
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1355 - val_loss: 0.3299
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1033 - val_loss: 0.3205
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0866 - val_loss: 0.3107
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0854 - val_loss: 0.3027
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0918 - val_loss: 0.2982
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0944 - val_loss: 0.2970
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0904 - val_loss: 0.2979
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0831 - val_loss: 0.2999
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0763 - val_loss: 0.3020
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0721 - val_loss: 0.3035
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0706 - val_loss: 0.3039
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0708 - val_loss: 0.3030
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0711 - val_loss: 0.3008
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0709 - val_loss: 0.2975
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0699 - val_loss: 0.2934
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0681 - val_loss: 0.2886
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0659 - val_loss: 0.2836
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0637 - val_loss: 0.2785
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0619 - val_loss: 0.2737
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0604 - val_loss: 0.2694
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0594 - val_loss: 0.2656
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0588 - val_loss: 0.2624
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0581 - val_loss: 0.2595
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0572 - val_loss: 0.2569
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0562 - val_loss: 0.2543
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0551 - val_loss: 0.2516
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0539 - val_loss: 0.2488
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0527 - val_loss: 0.2458
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0517 - val_loss: 0.2428
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0507 - val_loss: 0.2395
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0498 - val_loss: 0.2361
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0489 - val_loss: 0.2325
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0480 - val_loss: 0.2287
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0471 - val_loss: 0.2245
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0462 - val_loss: 0.2201
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0452 - val_loss: 0.2155
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0442 - val_loss: 0.2108
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0433 - val_loss: 0.2060
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0426 - val_loss: 0.2013
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0419 - val_loss: 0.1967
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0412 - val_loss: 0.1920
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0406 - val_loss: 0.1872
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0400 - val_loss: 0.1822
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0394 - val_loss: 0.1771
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0389 - val_loss: 0.1720
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0384 - val_loss: 0.1671
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0380 - val_loss: 0.1625
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0376 - val_loss: 0.1582
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0373 - val_loss: 0.1540
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0370 - val_loss: 0.1500
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0367 - val_loss: 0.1459
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0364 - val_loss: 0.1419
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0361 - val_loss: 0.1380
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0358 - val_loss: 0.1343
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0355 - val_loss: 0.1308
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0352 - val_loss: 0.1276
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0349 - val_loss: 0.1247
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0347 - val_loss: 0.1218
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0344 - val_loss: 0.1193
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0342 - val_loss: 0.1170
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0340 - val_loss: 0.1151
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0338 - val_loss: 0.1134
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0336 - val_loss: 0.1120
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0334 - val_loss: 0.1106
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0333 - val_loss: 0.1091
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0332 - val_loss: 0.1077
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0331 - val_loss: 0.1065
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0329 - val_loss: 0.1056
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0328 - val_loss: 0.1048
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0328 - val_loss: 0.1043
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0327 - val_loss: 0.1038
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0326 - val_loss: 0.1034
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0326 - val_loss: 0.1032
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0325 - val_loss: 0.1032
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0324 - val_loss: 0.1030
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0324 - val_loss: 0.1028
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0323 - val_loss: 0.1026
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0323 - val_loss: 0.1025
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0322 - val_loss: 0.1025
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0322 - val_loss: 0.1024
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0322 - val_loss: 0.1021
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0321 - val_loss: 0.1018
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0320 - val_loss: 0.1015
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0320 - val_loss: 0.1013
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0319 - val_loss: 0.1012
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0319 - val_loss: 0.1010
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0318 - val_loss: 0.1005
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0317 - val_loss: 0.1000
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0317 - val_loss: 0.0997
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0316 - val_loss: 0.0994
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0315 - val_loss: 0.0992
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0315 - val_loss: 0.0989
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0314 - val_loss: 0.0984
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0313 - val_loss: 0.0980
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0312 - val_loss: 0.0976
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0312 - val_loss: 0.0974
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0311 - val_loss: 0.0973
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0310 - val_loss: 0.0971
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 183
#     180 bezier_to_svg(input_beziers_padded, filename=input_svg_path)
#     181 bezier_to_svg(solution_beziers_padded, filename=solution_svg_path)
# --> 183 input_png_path = polylines2svg(input_beziers_padded, svg_path=input_svg_path)
#     184 solution_png_path = polylines2svg(solution_beziers_padded, svg_path=solution_svg_path)
#     186 print(f"Input PNG saved to: {input_png_path}")
#
# Cell In[1], line 100, in polylines2svg(paths_XYs, svg_path)
#      98 for path_XYs in paths_XYs:
#      99     for XY in path_XYs:
# --> 100         W, H = max(W, np.max(XY[:, 0])), max(H, np.max(XY[:, 1]))
#     101 padding = 0.1
#     102 W, H = int(W + padding * W), int(H + padding * H)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
